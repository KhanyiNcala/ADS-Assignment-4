# %%
import pandas as pd

path = r'C:\Users\9812170414089\ADS-Assignment-4\WA_Fn-UseC_-Telco-Customer-Churn.csv'
df= pd.read_csv(path)

# %%
#1a.Which 2 demographics have proven to be the most popular with the telco brand?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df['TotalCharges'].dtypes
# Out:
# dtype('O')

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'] , errors='coerce')
df['TotalCharges'].dtypes
# Out:
# dtype('float64')

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
gender_freq = df['gender'].value_counts()
senior_freq = df['SeniorCitizen'].value_counts()
print(gender_freq)
print(senior_freq)
# Out:
# Male      3555
# Female    3488
# Name: gender, dtype: int64
# 0    5901
# 1    1142
# Name: SeniorCitizen, dtype: int64

# %%
df['Count']=1

# %%
df1=df[['gender','SeniorCitizen','Count']]
df1
# Out:
#       gender  SeniorCitizen  Count
# 0     Female              0      1
# 1       Male              0      1
# 2       Male              0      1
# 3       Male              0      1
# 4     Female              0      1
# ...      ...            ...    ...
# 7038    Male              0      1
# 7039  Female              0      1
# 7040  Female              0      1
# 7041    Male              1      1
# 7042    Male              0      1
#
# [7043 rows x 3 columns]

# %%
df2=df1.groupby(['gender','SeniorCitizen']).count()
df2
# Out:
#                       Count
# gender SeniorCitizen
# Female 0               2920
#        1                568
# Male   0               2981
#        1                574

# %%
import matplotlib.pyplot as plt
import numpy as np

labels = ['Female', 'Male']
senior_citizen_0 = [2920, 2981]
senior_citizen_1 = [568, 574]

fig, ax = plt.subplots()
ax.bar(labels, senior_citizen_0, label='Not Senior Citizen', color='b')
ax.bar(labels, senior_citizen_1, bottom=senior_citizen_0, label='Senior Citizen', color='r')

ax.set_ylabel('Count')
ax.set_title('Counts by Gender and Senior Citizen Status')
ax.legend()

plt.show()

#Male, Senior Citizens

# %%
#a.)The Male Non-Senior Citizens have proven to be the most popular with the telco brand

# %%
# 1b. If the marketing team wanted to increase customer retention, to whom should
# they target their advertisements to?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df_churning = df[['PhoneService', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'MonthlyCharges', 'Contract', 'Churn']][df['Churn'] == "Yes"]

df_churning.head()
# Out:
#    PhoneService InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 2           Yes             DSL            Yes          Yes               No
# 4           Yes     Fiber optic             No           No               No
# 5           Yes     Fiber optic             No           No              Yes
# 8           Yes     Fiber optic             No           No              Yes
# 13          Yes     Fiber optic             No          Yes              Yes
#
#    TechSupport StreamingTV StreamingMovies  MonthlyCharges        Contract  \
# 2           No          No              No           53.85  Month-to-month
# 4           No          No              No           70.70  Month-to-month
# 5           No         Yes             Yes           99.65  Month-to-month
# 8          Yes         Yes             Yes          104.80  Month-to-month
# 13          No         Yes             Yes          103.70  Month-to-month
#
#    Churn
# 2    Yes
# 4    Yes
# 5    Yes
# ...

# %%
# Get count of "Yes" values for each column of interest
for column in df_churning.columns:
    if column not in ['Churn']:
        print(df_churning[column].value_counts())
# Out:
# Yes    4662
# No      512
# Name: PhoneService, dtype: int64
# DSL            1962
# Fiber optic    1799
# No             1413
# Name: InternetService, dtype: int64
# No                     2037
# Yes                    1724
# No internet service    1413
# Name: OnlineSecurity, dtype: int64
# Yes                    1906
# No                     1855
# No internet service    1413
# Name: OnlineBackup, dtype: int64
# No                     1884
# Yes                    1877
# No internet service    1413
# Name: DeviceProtection, dtype: int64
# No                     2027
# Yes                    1734
# No internet service    1413
# Name: TechSupport, dtype: int64
# Yes                    1893
# No                     1868
# No internet service    1413
# Name: StreamingTV, dtype: int64
# Yes                    1914
# No                     1847
# No internet service    1413
# Name: StreamingMovies, dtype: int64
# 20.05     58
# 19.70     41
# 19.95     41
# 19.85     40
# 19.90     40
# ...

# %%
df_churning.columns
# Out:
# Index(['PhoneService', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'MonthlyCharges', 'Contract', 'Churn'],
#       dtype='object')

# %%
df_churning1 = df[['PhoneService', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'MonthlyCharges', 'Contract', 'Churn']][df['Churn'] == "No"]

df_churning1.head()
# Out:
#   PhoneService InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 0           No             DSL             No          Yes               No
# 1          Yes             DSL            Yes           No              Yes
# 3           No             DSL            Yes           No              Yes
# 6          Yes     Fiber optic             No          Yes               No
# 7           No             DSL            Yes           No               No
#
#   TechSupport StreamingTV StreamingMovies  MonthlyCharges        Contract  \
# 0          No          No              No           29.85  Month-to-month
# 1          No          No              No           56.95        One year
# 3         Yes          No              No           42.30        One year
# 6          No         Yes              No           89.10  Month-to-month
# 7          No          No              No           29.75  Month-to-month
#
#   Churn
# 0    No
# 1    No
# 3    No
# 6    No
# 7    No

# %%
df_churning1.columns
# Out:
# Index(['PhoneService', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'MonthlyCharges', 'Contract', 'Churn'],
#       dtype='object')

# %%
for column in df_churning1.columns:
    if column not in ['Churn']:
        print(df_churning1[column].value_counts())
# Out:
# Yes    4662
# No      512
# Name: PhoneService, dtype: int64
# DSL            1962
# Fiber optic    1799
# No             1413
# Name: InternetService, dtype: int64
# No                     2037
# Yes                    1724
# No internet service    1413
# Name: OnlineSecurity, dtype: int64
# Yes                    1906
# No                     1855
# No internet service    1413
# Name: OnlineBackup, dtype: int64
# No                     1884
# Yes                    1877
# No internet service    1413
# Name: DeviceProtection, dtype: int64
# No                     2027
# Yes                    1734
# No internet service    1413
# Name: TechSupport, dtype: int64
# Yes                    1893
# No                     1868
# No internet service    1413
# Name: StreamingTV, dtype: int64
# Yes                    1914
# No                     1847
# No internet service    1413
# Name: StreamingMovies, dtype: int64
# 20.05     58
# 19.70     41
# 19.95     41
# 19.85     40
# 19.90     40
# ...

# %%
# 2a. Which 3 services are contributing to a higher monthly charge and resulting to
# customers churning? (Use visualizations in explaining your analysis)

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges   Count
# count    7043.000000  7043.000000     7043.000000   7032.000000  7043.0
# mean        0.162147    32.371149       64.761692   2283.300441     1.0
# std         0.368612    24.559481       30.090047   2266.771362     0.0
# min         0.000000     0.000000       18.250000     18.800000     1.0
# 25%         0.000000     9.000000       35.500000    401.450000     1.0
# 50%         0.000000    29.000000       70.350000   1397.475000     1.0
# 75%         0.000000    55.000000       89.850000   3794.737500     1.0
# max         1.000000    72.000000      118.750000   8684.800000     1.0

# %%
higherprice =df[['PhoneService','InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
            'TechSupport','StreamingTV', 'StreamingMovies', 'MonthlyCharges', 'Churn']][df['MonthlyCharges'] == 118.75]
higherprice
#in this case we want to see the service that is bring alot of money to the company
# Out:
#      PhoneService InternetService OnlineSecurity OnlineBackup  \
# 4586          Yes     Fiber optic            Yes          Yes
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies  MonthlyCharges  \
# 4586              Yes         Yes         Yes             Yes          118.75
#
#      Churn
# 4586    No

# %%
import seaborn as sns

for col in ['PhoneService', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
            'TechSupport','StreamingTV', 'StreamingMovies']:
        plt.figure(figsize=(4,2)) 
        sns.lineplot(data=df,x=col, y='MonthlyCharges', hue='Churn', palette="tab10")
        plt.show()

# %%
# 2b. If the telco was to offer Phone as a standalone service, which type of contract
# would encourage customer retention?

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... TechSupport  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
# 2                No             DSL            Yes  ...          No
# 3  No phone service             DSL            Yes  ...         Yes
# 4                No     Fiber optic             No  ...          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
df['Contract'].value_counts()
# Out:
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: Contract, dtype: int64

# %%
phonecontract=df.groupby(["PhoneService", "Contract"])["Count"].count().reset_index()
phonecontract
# Out:
#   PhoneService        Contract  Count
# 0           No  Month-to-month    376
# 1           No        One year    145
# 2           No        Two year    161
# 3          Yes  Month-to-month   3499
# 4          Yes        One year   1328
# 5          Yes        Two year   1534

# %%
phonecontract=df.groupby(["PhoneService", "Contract"])["Count"].count().reset_index()
plt.figure(figsize=(4,4))
sns.countplot(x="PhoneService", hue="Contract", data=df)
plt.xlabel("PhoneService")
plt.ylabel("No of subscribers")
# Out:
# Text(0, 0.5, 'No of subscribers')

# %%
# If the telco was to offer Phone as a standalone service, the month-to-month is the most preferred contract compared to the two 
# other contracts.

# %%
#3a. Payment: (Use visualizations in explaining your analysis)
# If the company was to streamline all its services into 3 bouquet packages, what
# monthly prices will be appropriate for the following packages to keep customers
# from churning:

# %%
df2 = df[['MonthlyCharges','Churn','Count']]
df2
# Out:
#       MonthlyCharges Churn  Count
# 0              29.85    No      1
# 1              56.95    No      1
# 2              53.85   Yes      1
# 3              42.30    No      1
# 4              70.70   Yes      1
# ...              ...   ...    ...
# 7038           84.80    No      1
# 7039          103.20    No      1
# 7040           29.60    No      1
# 7041           74.40   Yes      1
# 7042          105.65    No      1
#
# [7043 rows x 3 columns]

# %%
df2.groupby(['MonthlyCharges','Churn']).count().reset_index()
# Out:
#       MonthlyCharges Churn  Count
# 0              18.25    No      1
# 1              18.40    No      1
# 2              18.55    No      1
# 3              18.70    No      2
# 4              18.75    No      1
# ...              ...   ...    ...
# 2365          118.20    No      1
# 2366          118.35   Yes      1
# 2367          118.60    No      2
# 2368          118.65    No      1
# 2369          118.75    No      1
#
# [2370 rows x 3 columns]

# %%
plt.figure(figsize=(12,5))
sns.displot(x="MonthlyCharges", hue ="Churn", data=df,kde=True)
plt.xlabel("MonthlyCharges")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# 3b. Should the company strictly go paperless for their monthly billings as a technique
# of keeping their customers and why?

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... TechSupport  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
# 2                No             DSL            Yes  ...          No
# 3  No phone service             DSL            Yes  ...         Yes
# 4                No     Fiber optic             No  ...          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
df['PaperlessBilling'].value_counts()
# Out:
# Yes    4171
# No     2872
# Name: PaperlessBilling, dtype: int64

# %%
sns.countplot(x="PaperlessBilling", hue="Churn", data=df)
plt.xlabel("PaperlessBilling")
plt.ylabel("No of subscribers")
# Out:
# Text(0, 0.5, 'No of subscribers')

# %%
# Yes, the company should go paperless for their monthly billings as a technique as in the illustartion we can see that there is 
# more number of subscribers when the company goes for paperless billing
